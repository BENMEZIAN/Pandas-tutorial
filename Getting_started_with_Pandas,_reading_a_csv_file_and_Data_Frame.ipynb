# %% [markdown]
# <a href="https://colab.research.google.com/github/BENMEZIAN/Pandas-tutorial/blob/main/Getting_started_with_Pandas%2C_reading_a_csv_file_and_Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import pandas library

# %%
import pandas as pd

# %% [markdown]
# ### Read csv file (first dataset)

# %%
df = pd.read_csv('sell_store_data.csv')
df
# Out:
#      BranchName  Week  DayWeek  Day  Month  Hour Transaction_Type  Units  \
# 0       MyStore     1        3    2      1     9             Card      3
# 1       MyStore     1        3    2      1    10             Cash      7
# 2       MyStore     1        3    2      1    10             Card      7
# 3       MyStore     1        3    2      1    11             Card     20
# 4       MyStore     1        3    2      1    12             Cash      1
# ...         ...   ...      ...  ...    ...   ...              ...    ...
# 4095    MyStore    53        1   31     12    13             Card     10
# 4096    MyStore    53        1   31     12    14             Cash     32
# 4097    MyStore    53        1   31     12    14             Card      5
# 4098    MyStore    53        1   31     12    15             Cash     66
# 4099    MyStore    53        1   31     12    15             Card      4
#
#         Amount
# 0       $54.00
# 1      -$17.80
# 2       $41.99
# 3      $412.50
# ...

# %% [markdown]
# ### Dimension of the dataset

# %%
df.shape
# Out:
# (4100, 9)

# %% [markdown]
# ### Display 5 first rows

# %%
df.head()
# Out:
#   BranchName  Week  DayWeek  Day  Month  Hour Transaction_Type  Units   Amount
# 0    MyStore     1        3    2      1     9             Card      3   $54.00
# 1    MyStore     1        3    2      1    10             Cash      7  -$17.80
# 2    MyStore     1        3    2      1    10             Card      7   $41.99
# 3    MyStore     1        3    2      1    11             Card     20  $412.50
# 4    MyStore     1        3    2      1    12             Cash      1  -$18.00

# %% [markdown]
# ### Display last 5 rows

# %%
df.tail()
# Out:
#      BranchName  Week  DayWeek  Day  Month  Hour Transaction_Type  Units  \
# 4095    MyStore    53        1   31     12    13             Card     10
# 4096    MyStore    53        1   31     12    14             Cash     32
# 4097    MyStore    53        1   31     12    14             Card      5
# 4098    MyStore    53        1   31     12    15             Cash     66
# 4099    MyStore    53        1   31     12    15             Card      4
#
#         Amount
# 4095   $129.00
# 4096   -$68.36
# 4097    $71.00
# 4098  -$359.18
# 4099   $130.00

# %% [markdown]
# ### Display given number of rows (for example 10)

# %%
df.head(10)
# Out:
#   BranchName  Week  DayWeek  Day  Month  Hour Transaction_Type  Units   Amount
# 0    MyStore     1        3    2      1     9             Card      3   $54.00
# 1    MyStore     1        3    2      1    10             Cash      7  -$17.80
# 2    MyStore     1        3    2      1    10             Card      7   $41.99
# 3    MyStore     1        3    2      1    11             Card     20  $412.50
# 4    MyStore     1        3    2      1    12             Cash      1  -$18.00
# 5    MyStore     1        3    2      1    12             Card      1   -$5.00
# 6    MyStore     1        3    2      1    12             Card     15  $118.50
# 7    MyStore     1        3    2      1    13             Cash     90  -$94.92
# 8    MyStore     1        3    2      1    13             Card     28  $423.50
# 9    MyStore     1        3    2      1    14             Cash     34  -$95.39

# %% [markdown]
# ### Read csv file (second dataset)

# %%
df_titanic = pd.read_csv('titanic_data.csv')
df_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
pd.set_option('display.max_columns', 1309)

# %%
df_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
